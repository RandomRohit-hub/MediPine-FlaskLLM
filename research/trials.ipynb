# %%
print('ok')
# Out:
# ok

# %%
# %pwd
# Out:
# 'd:\\XXX.BADI BAAT CHEET.XXX\\ML PROJ\\MediPine-FlaskLLM\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\XXX.BADI BAAT CHEET.XXX\\ML PROJ\\MediPine-FlaskLLM'
